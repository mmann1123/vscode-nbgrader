# %% [markdown]
# # test 1
# create a variable x and assign it the value 10

# %%
### BEGIN SOLUTION
x =10
### END SOLUTION

# %%
#assertions
assert x == 10, "The value of x should be 10"

# %%
assert x == 10, "The value of x should be 10"
